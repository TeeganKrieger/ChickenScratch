# %%
import numpy as np
import random
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import os
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import seaborn; seaborn.set()
from keras.callbacks import EarlyStopping

data_path = os.path.join(os.getcwd(), "../Traing Data Preprocessing/Training Data/Processed")

X = []
Y = []
X_val = []
Y_val = []

namesToClass = {
    "lowera": 0,
    "lowerb": 1,
    "lowerc": 2,
    "lowerd": 3,
    "lowere": 4,
    "lowerf": 5,
    "lowerg": 6,
    "lowerh": 7,
    "loweri": 8,
    "lowerj": 9,
    "lowerk": 10,
    "lowerl": 11,
    "lowerm": 12,
    "lowern": 13,
    "lowero": 14,
    "lowerp": 15,
    "lowerq": 16,
    "lowerr": 17,
    "lowers": 18,
    "lowert": 19,
    "loweru": 20,
    "lowerv": 21,
    "lowerw": 22,
    "lowerx": 23,
    "lowery": 24,
    "lowerz": 25,
    "upperA": 26,
    "upperB": 27,
    "upperC": 28,
    "upperD": 29,
    "upperE": 30,
    "upperF": 31,
    "upperG": 32,
    "upperH": 33,
    "upperI": 34,
    "upperJ": 35,
    "upperK": 36,
    "upperL": 37,
    "upperM": 38,
    "upperN": 39,
    "upperO": 40,
    "upperP": 41,
    "upperQ": 42,
    "upperR": 43,
    "upperS": 44,
    "upperT": 45,
    "upperU": 46,
    "upperV": 47,
    "upperW": 48,
    "upperX": 49,
    "upperY": 50,
    "upperZ": 51,
    "num1": 52,
    "num2": 53,
    "num3" : 54,
    "num4" : 55,
    "num5": 56,
    "num6": 57,
    "num7": 58,
    "num8": 59,
    "num9": 60,
    "num0": 61,
    "exclamation": 62,
    "at": 63,
    "pound": 64,
    "dollar": 65,
    "percent": 66,
    "caret": 67,
    "and": 68,
    "asterisk": 69,
    "openPar": 70,
    "closePar": 71,
    "hyphen": 72,
    "underscore": 73,
    "plus": 74,
    "equals": 75,
    "openBrace": 76,
    "closeBrace": 77,
    "openSquare": 78,
    "closeSquare": 79,
    "pipe": 80,
    "backslash": 81,
    "colon": 82,
    "semicolon": 83,
    "quote": 84,
    "apostrophe": 85,
    "openTriangle": 86,
    "closeTriangle": 87,
    "comma", 88,
    "period": 89,
    "forwardSlash": 90,
    "question": 91,
    "tilde": 92,
    "grave": 93
}

for root, dirs, files in os.walk(data_path, topdown=False):
    for f in files:
        key = f[0 : 6]
        if key in namesToClass:
            img = load_img(os.path.join(root, f))
            arr = img_to_array(img)
            #arr.reshape((1,) + arr.shape)
            
            if random.randint(1,100) > 80:
                X_val.append(arr)
                Y_val.append(namesToClass[key])
            else:
                X.append(arr)
                Y.append(namesToClass[key])

X = np.array(X)
Y = np.array(Y)
X_val = np.array(X_val)
Y_val = np.array(Y_val)

print(X.shape)
print(Y.shape)

model = Sequential()
model.add(Conv2D(64, (3, 2), activation='relu', input_shape=(18, 13, 3)))
model.add(Conv2D(128, (3, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3, 2), activation='relu'))
model.add(Conv2D(256, (3, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(124, activation='relu'))
model.add(Dense(62, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# (4719, 18, 13, 3)
# (4719,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 12, 64)        1216
#
#  conv2d_1 (Conv2D)           (None, 14, 11, 128)       49280
#
#  max_pooling2d (MaxPooling2D  (None, 7, 5, 128)        0
#  )
#
#  conv2d_2 (Conv2D)           (None, 5, 4, 128)         98432
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 256)         196864
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 124)               31868
#
#  dense_1 (Dense)             (None, 62)                7750
#
# =================================================================
# Total params: 385,410
# Trainable params: 385,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
#es = EarlyStopping(monitor='val_accuracy', mode='max', min_delta=0.01)

model.fit(X, Y, epochs=50, validation_data=(X_val, Y_val))

y_predicted = model.predict(X_val)
y_predicted = np.argmax(y_predicted, axis=1)

#Get metrics
print(Y_val)
print(y_predicted)
print(metrics.classification_report(Y_val, y_predicted))

#Draw confusion matrix
matrix = metrics.confusion_matrix(Y_val, y_predicted)
hm = seaborn.heatmap(matrix, annot=True, fmt='d')
bottom, top = hm.get_ylim()
hm.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# Epoch 1/50
# 148/148 [==============================] - 3s 21ms/step - loss: 4.9038 - accuracy: 0.0206 - val_loss: 3.9581 - val_accuracy: 0.0331
# Epoch 2/50
# 148/148 [==============================] - 3s 19ms/step - loss: 3.8002 - accuracy: 0.0619 - val_loss: 3.4628 - val_accuracy: 0.0918
# Epoch 3/50
# 148/148 [==============================] - 3s 19ms/step - loss: 3.0605 - accuracy: 0.1854 - val_loss: 2.7240 - val_accuracy: 0.2283
# Epoch 4/50
# 148/148 [==============================] - 3s 19ms/step - loss: 2.3107 - accuracy: 0.3437 - val_loss: 2.1358 - val_accuracy: 0.3904
# Epoch 5/50
# 148/148 [==============================] - 3s 19ms/step - loss: 1.7282 - accuracy: 0.4846 - val_loss: 1.7040 - val_accuracy: 0.4682
# Epoch 6/50
# 148/148 [==============================] - 3s 19ms/step - loss: 1.3549 - accuracy: 0.5751 - val_loss: 1.6197 - val_accuracy: 0.4905
# Epoch 7/50
# 148/148 [==============================] - 3s 19ms/step - loss: 1.0823 - accuracy: 0.6533 - val_loss: 1.3867 - val_accuracy: 0.5624
# Epoch 8/50
# 148/148 [==============================] - 3s 20ms/step - loss: 0.8746 - accuracy: 0.7139 - val_loss: 1.3551 - val_accuracy: 0.5897
# Epoch 9/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.7163 - accuracy: 0.7614 - val_loss: 1.2561 - val_accuracy: 0.6146
# Epoch 10/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.5768 - accuracy: 0.8044 - val_loss: 1.2570 - val_accuracy: 0.6187
# Epoch 11/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.4765 - accuracy: 0.8373 - val_loss: 1.1933 - val_accuracy: 0.6617
# Epoch 12/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.3852 - accuracy: 0.8642 - val_loss: 1.1770 - val_accuracy: 0.6923
# Epoch 13/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.3226 - accuracy: 0.8828 - val_loss: 1.2757 - val_accuracy: 0.6725
# Epoch 14/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.3634 - accuracy: 0.8729 - val_loss: 1.4028 - val_accuracy: 0.6642
# Epoch 15/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2721 - accuracy: 0.9108 - val_loss: 1.3198 - val_accuracy: 0.6749
# Epoch 16/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2484 - accuracy: 0.9176 - val_loss: 1.3857 - val_accuracy: 0.6650
# Epoch 17/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2237 - accuracy: 0.9303 - val_loss: 1.3294 - val_accuracy: 0.6890
# Epoch 18/50
# 148/148 [==============================] - 3s 22ms/step - loss: 0.2402 - accuracy: 0.9220 - val_loss: 1.4791 - val_accuracy: 0.6791
# Epoch 19/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2017 - accuracy: 0.9282 - val_loss: 1.5147 - val_accuracy: 0.6824
# Epoch 20/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2073 - accuracy: 0.9339 - val_loss: 1.5721 - val_accuracy: 0.6898
# Epoch 21/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1667 - accuracy: 0.9396 - val_loss: 1.7781 - val_accuracy: 0.6419
# Epoch 22/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2125 - accuracy: 0.9294 - val_loss: 1.7765 - val_accuracy: 0.6799
# Epoch 23/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2012 - accuracy: 0.9322 - val_loss: 1.5683 - val_accuracy: 0.6898
# Epoch 24/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1789 - accuracy: 0.9383 - val_loss: 1.7051 - val_accuracy: 0.6741
# Epoch 25/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1502 - accuracy: 0.9547 - val_loss: 1.7785 - val_accuracy: 0.6675
# Epoch 26/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1124 - accuracy: 0.9638 - val_loss: 1.8459 - val_accuracy: 0.6890
# Epoch 27/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1603 - accuracy: 0.9474 - val_loss: 1.6626 - val_accuracy: 0.6923
# Epoch 28/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1628 - accuracy: 0.9458 - val_loss: 1.7717 - val_accuracy: 0.6741
# Epoch 29/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1620 - accuracy: 0.9481 - val_loss: 1.6831 - val_accuracy: 0.6758
# Epoch 30/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1794 - accuracy: 0.9405 - val_loss: 1.6301 - val_accuracy: 0.6534
# Epoch 31/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0869 - accuracy: 0.9727 - val_loss: 1.8079 - val_accuracy: 0.6882
# Epoch 32/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1184 - accuracy: 0.9644 - val_loss: 2.2159 - val_accuracy: 0.6576
# Epoch 33/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2733 - accuracy: 0.9167 - val_loss: 1.9270 - val_accuracy: 0.6642
# Epoch 34/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1499 - accuracy: 0.9472 - val_loss: 1.6630 - val_accuracy: 0.7072
# Epoch 35/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0723 - accuracy: 0.9761 - val_loss: 2.0176 - val_accuracy: 0.6998
# Epoch 36/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1414 - accuracy: 0.9557 - val_loss: 1.9335 - val_accuracy: 0.6667
# Epoch 37/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1160 - accuracy: 0.9642 - val_loss: 2.1962 - val_accuracy: 0.6824
# Epoch 38/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1712 - accuracy: 0.9481 - val_loss: 2.4635 - val_accuracy: 0.6369
# Epoch 39/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.2065 - accuracy: 0.9343 - val_loss: 1.7541 - val_accuracy: 0.6849
# Epoch 40/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0753 - accuracy: 0.9727 - val_loss: 1.9169 - val_accuracy: 0.6981
# Epoch 41/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0874 - accuracy: 0.9739 - val_loss: 2.0520 - val_accuracy: 0.6716
# Epoch 42/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0711 - accuracy: 0.9739 - val_loss: 2.3534 - val_accuracy: 0.6782
# Epoch 43/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1772 - accuracy: 0.9496 - val_loss: 2.3432 - val_accuracy: 0.6642
# Epoch 44/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1232 - accuracy: 0.9602 - val_loss: 1.9931 - val_accuracy: 0.6749
# Epoch 45/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.1071 - accuracy: 0.9688 - val_loss: 1.9297 - val_accuracy: 0.6948
# Epoch 46/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0506 - accuracy: 0.9833 - val_loss: 2.2234 - val_accuracy: 0.6807
# Epoch 47/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0865 - accuracy: 0.9725 - val_loss: 2.5085 - val_accuracy: 0.6493
# Epoch 48/50
# 148/148 [==============================] - 3s 21ms/step - loss: 0.0852 - accuracy: 0.9729 - val_loss: 2.0519 - val_accuracy: 0.6824
# Epoch 49/50
# 148/148 [==============================] - 3s 22ms/step - loss: 0.0380 - accuracy: 0.9896 - val_loss: 2.1429 - val_accuracy: 0.6923
# Epoch 50/50
# 148/148 [==============================] - 3s 22ms/step - loss: 0.0701 - accuracy: 0.9784 - val_loss: 2.3893 - val_accuracy: 0.6667
# [ 0  0  0 ... 51 51 51]
# [ 0  0 22 ... 51 51 51]
#               precision    recall  f1-score   support
#
#            0       0.58      0.60      0.59        25
#            1       0.80      0.87      0.83        23
#            2       0.34      0.62      0.44        24
#            3       1.00      0.70      0.82        23
#            4       1.00      0.38      0.56        26
#            5       0.50      0.74      0.60        19
#            6       0.79      0.48      0.60        31
#            7       0.69      0.50      0.58        22
#            8       0.73      0.73      0.73        26
#            9       0.83      0.58      0.68        33
#           10       0.38      0.45      0.41        20
#           11       0.84      0.57      0.68        28
#           12       0.78      0.78      0.78        23
#           13       0.48      0.62      0.54        16
#           14       0.41      0.70      0.52        10
#           15       0.43      0.52      0.47        23
#           16       0.67      0.76      0.71        29
#           17       0.67      0.96      0.79        23
#           18       0.81      0.70      0.75        30
#           19       0.67      0.70      0.68        23
#           20       0.59      0.48      0.53        27
#           21       0.37      0.79      0.50        24
#           22       0.72      0.43      0.54        30
#           23       0.40      0.46      0.43        13
#           24       0.64      0.76      0.70        21
#           25       0.59      0.81      0.68        16
#           26       0.92      0.44      0.59        25
#           27       0.67      0.83      0.74        24
#           28       0.59      0.52      0.55        25
#           29       0.64      0.61      0.62        23
#           30       0.88      0.75      0.81        28
#           31       0.63      0.79      0.70        24
#           32       0.61      0.64      0.62        22
#           33       0.96      0.89      0.93        28
#           34       0.53      0.84      0.65        19
#           35       0.75      0.71      0.73        21
#           36       0.52      0.55      0.53        22
#           37       0.88      0.79      0.83        19
#           38       0.75      0.45      0.56        20
#           39       0.61      0.85      0.71        20
#           40       0.43      0.64      0.51        14
#           41       0.70      0.73      0.72        26
#           42       0.88      0.65      0.75        23
#           43       0.94      0.65      0.77        23
#           44       0.50      0.72      0.59        18
#           45       0.87      0.95      0.91        21
#           46       0.82      0.48      0.61        29
#           47       0.67      0.59      0.63        27
#           48       0.95      0.75      0.84        28
#           49       0.89      0.76      0.82        21
#           50       0.90      0.76      0.83        25
#           51       0.91      0.81      0.86        26
#
#     accuracy                           0.67      1209
#    macro avg       0.69      0.67      0.66      1209
# weighted avg       0.71      0.67      0.67      1209
# (52.5, -0.5)
