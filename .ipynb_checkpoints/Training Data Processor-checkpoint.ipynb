# %%
from PIL import Image, ImageFilter
import os
im = Image.open(os.path.join(os.getcwd(), 'Training Data/Raw/Test.png'))
width, height = im.size
display(im)

x, y, w, h = 50, 50, 94, 110
for j in range(0, 15):
    print(y)
    print(h)
    for i in range(0,14):
        if (i % 7 == 0):
            x+=48
            w+=48
            continue
        region = im.crop((x,y,w,h))
        display(region)
        x+=48
        w+=48
    x = 50
    w = 94
    y+=64
    h+=64
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=816x1056 at 0x20F744E8D88>
# 50
# 110
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DFE88>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DE6C8>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F74447D48>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DED48>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DF488>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DFE88>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DED48>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DE6C8>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DF488>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DE6C8>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DED48>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F744DF488>
# 114
# 174
# <PIL.Image.Image image mode=P size=44x60 at 0x20F74447A48>
# <PIL.Image.Image image mode=P size=44x60 at 0x20F74447748>
# ...
